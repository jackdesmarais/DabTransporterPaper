# %%
# cd /Volumes/Shared/data/Jack/SavageLab/scripts/
# Out:
# /Volumes/Shared/data/Jack/SavageLab/scripts

# %%
cd /Users/jackdesmarais/Documents/berkeley/SavageLab/excelSheetsWithEquationsAndData/
# Out:
# /Users/jackdesmarais/Documents/berkeley/SavageLab/excelSheetsWithEquationsAndData

# %%
from matplotlib import pyplot as plt
import matplotlib

# %%
# # Making Panel C
# %matplotlib inline


# def getExcitationScan(filename):
#     import numpy as np
#     file = open(filename, 'r')
#     graph = [line.split() for line in file if line[0].isdigit()]
#     file.close()
#     return(np.array([float(i[0]) for i in graph]),np.array([float(i[1]) for i in graph]))
# # getExcitationScan('/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2-Batch5/xraySpectroscpy/Acetone_BCA_Se_001.bip')

# def makePanelD(ax):
#     x,y=getExcitationScan('/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2-Batch5/xraySpectroscpy/Acetone_BCA_Se_001.bip')
#     y=y/max(y[(x>2000) & (x<3500)])
#     ax.plot(x,y,label='Bovine Erythrocyte CA',zorder=5)
    
#     x,y=getExcitationScan('/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2-Batch5/xraySpectroscpy/Acetone_DAB2_SEDC_Se_001.bip')
#     y=(y/max(y[(x>2000) & (x<3500)]))+2
#     ax.plot(x,y,label='DAB2',zorder=5)
#     plt.xlim(2000,12000)
#     plt.ylim(0,5)
    
#     x,y=getExcitationScan('/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2-Batch5/xraySpectroscpy/bufferBlank_03_Se_001.bip')
#     y=(y/max(y[(x>2000) & (x<3500)]))+4
#     ax.plot(x,y,label='Buffer Blank',zorder=5)
    
# #     plt.vlines([2622.39,2815.6,7478.15,8638.86,9572.0],0,6,zorder=0 ,alpha=0.5)
#     plt.vlines([2622.39,7478.15,8638.86,9572.0],0,6,zorder=0 ,alpha=0.2,linestyles='--')
#     plt.annotate('Chlorine Ka1',[2622.39,5.5],[2722.39,5.8],arrowprops={'arrowstyle':'->'})
#     plt.annotate('Nickel Ka1',[7478.15,5.5],[6478.15,5.8],arrowprops={'arrowstyle':'->'})
#     plt.annotate('Zinc Ka1',[8638.86,5.5],[7738.86,5.8],arrowprops={'arrowstyle':'->'})
#     plt.annotate('Zinc Kb1',[9572.0,5.5],[8672.0,5.8],arrowprops={'arrowstyle':'->'})
#     plt.legend(loc=[0.72,0.8])
#     plt.xlim(2000,12000)
#     plt.ylim(0,6)
#     plt.xlabel('Energy (eV)',fontsize=15)
#     plt.ylabel('Normalized counts',fontsize=15)
    
# fig,ax = plt.subplots(figsize=(10,10), frameon=False)
# makePanelD(ax)
# plt.show()

# %%
import seaborn as sns
cols = ['#56AC52','#337848','#F2E92A','#F58320','#822F31','#CC3C39','#475BA6','#78CDDA','#5375BA','#EA3C81'
        ,'#7E441D','#848585','#8E5EA7','#B9D36C','#000000']
colors = sns.color_palette(cols)
sns.palplot(colors)
plt.show()

# %%
# Making Panel C
# %matplotlib inline


def getExcitationScan(filename):
    import numpy as np
    file = open(filename, 'r')
    graph = [line.split() for line in file if line[0].isdigit()]
    file.close()
    return(np.array([float(i[0]) for i in graph]),np.array([float(i[1]) for i in graph]))
# getExcitationScan('/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2-Batch5/xraySpectroscpy/Acetone_BCA_Se_001.bip')

def makePanelD(ax):
    import pandas as pd
    import numpy as np
    matplotlib.rcParams.update({'font.size': 30})
    matplotlib.rcParams.update({'font.sans-serif': ['Helvetica']})
    print(matplotlib.rcParams['font.sans-serif'])
    import seaborn as sns
    cols = ['#56AC52','#337848','#F2E92A','#F58320','#822F31','#CC3C39','#475BA6','#78CDDA','#5375BA','#EA3C81'
        ,'#7E441D','#848585','#8E5EA7','#B9D36C','#000000']
    colors = sns.color_palette(cols)
    ncolors = [colors[0],colors[3],colors[7],colors[9],colors[12],colors[11]]
#     ncolors = sns.color_palette(cols)
    
    fileLoc = './zincBindingFilesForPaper/'
    plotOrder=['Buffer blank','Dab2 C351A','Dab2 D353A','Dab2','Bovine CA']
    toPlot = [
        ['Acetone_BCA_Se_001.bip','Bovine CA'],
        ['Acetone_DAB2_SEDC_Se_001.bip','Dab2'],
#         ['BCA_acetone_loopOnly.bip','Bovine CA loop'],
        ['bufferBlank_02_Se_001.bip','Buffer blank'],
        ['bufferBlank_03_Se_001.bip','Buffer blank'],
#         ['bufferBlank_Se_001.bip','buffer blank 3'],
#         ['DAB2_acetone_2.bip','DAB2 2'],
#         ['DAB2_acetone.bip','DAB2 3'],
#         ['',''],
#         ['',''],
#         ['',''],
#         ['',''],
#         ['',''],
#         ['',''],
#         ['',''],
#         ['cas9_acetone.bip','cas9'],
         ['BCA_acetone.bip','Bovine CA'],
         ['DAB2_acetone_3.bip','Dab2'],
         ['DAB2_DC_his_acetone.bip','Dab2 C351A'],
         ['DAB2_DC_strep_acetone.bip','Dab2 C351A'],
         ['DAB2_DD_strep_acetone_2.bip','Dab2 D353A'],
         ['DAB2_DD_strep_acetone.bip','Dab2 D353A'],
    ]
    data_df = pd.DataFrame(columns=['x'],dtype='float')
    for i, file in enumerate(toPlot):
        x,y=getExcitationScan(fileLoc+file[0])
        y=y/max(y[(x>2000) & (x<3500)])
        temp_df = pd.DataFrame(columns=['x',file[0]],dtype='float')
        temp_df['x'] = x
        temp_df[file[0]] = y
        temp_df.loc[-1] = ['name',file[1]]
        data_df = data_df.merge(temp_df, on='x',how='outer')
    data_df = data_df.set_index('x').transpose()
    for column in data_df:
        if column != 'name':
            data_df[column] = data_df[column].astype(float)
    data_df = data_df.groupby('name',axis=0).mean().transpose()[plotOrder]
#     return(data_df)
    x=data_df.index
    for i, col in enumerate(data_df.columns):
        y=data_df[col]+i*2
        ax.plot(x,y,zorder=5,lw=3,color=ncolors[i])
        plt.text(2900,(i*2)+0.3,col,ha='left',va='bottom')
        
    top=len(data_df.columns)*2+0.5
    plt.xlim(2000,12000)
    plt.ylim(-0.1,top)
    
    
#     plt.vlines([2622.39,2815.6,7478.15,8638.86,9572.0],0,6,zorder=0 ,alpha=0.5)
    plt.vlines([2622.39,6403.84,7478.15,8638.86,9572.0],0,top-0.5,zorder=0 ,alpha=0.5,linestyles='--',lw=3)
#     plt.text(2622.39,top-0.6,'Cl Ka1',ha='center',va='bottom')
#     plt.text(7478.15,top-0.6,'Ni Ka1',ha='center',va='bottom')
#     plt.text(8638.86,top-0.6,'Zn Ka1',ha='center',va='bottom')
#     plt.text(9572.0,top-0.6,'Zn Kb1',ha='center',va='bottom')
#     plt.text(6403.84,top-0.6,'Fe Ka1',ha='center',va='bottom')
    plt.text(2622.39,top-0.6,'Cl',ha='center',va='bottom')
    plt.text(7478.15,top-0.6,'Ni',ha='center',va='bottom')
    plt.text(8638.86,top-0.6,'Zn',ha='center',va='bottom')
    plt.text(9572.0,top-0.6,'Zn',ha='center',va='bottom')
    plt.text(6403.84,top-0.6,'Fe',ha='center',va='bottom')
#     plt.legend(loc=[1.05,0.4])
    plt.xlabel('Energy (eV)')
    plt.ylabel('Normalized counts')
    plt.yticks([])
    plt.xticks(rotation=45)
    
    plt.tick_params(axis='both', direction='out', bottom='on', left='on', top='off', right='off',
                    length=10, width=4)
        # Hide the right and top spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    # Only show ticks on the left and bottom spines
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')
    
#     change axis weight
    ax.spines['left'].set_linewidth(3)
    ax.spines['bottom'].set_linewidth(3)
    return(data_df)
    
fig,ax = plt.subplots(figsize=(10,10), frameon=False)
df = makePanelD(ax)
plt.savefig('./../scripts/FigureMakingForBarseqDABPaper/figsForPaper/fig4PanelD.eps',format='eps',bbox_inches='tight')

plt.show()
# df
# Out:
# ['Helvetica']
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
df[['buffer blank','Dab2 C351A','Dab2 D353A','Dab2','Bovine CA']]
# Out:
# name     buffer blank  Dab2 C351A  Dab2 D353A      Dab2  Bovine CA
# x
# 12.5         0.000000    0.000000    0.000000  0.000000   0.000000
# 37.5         0.000000    0.000000    0.000000  0.000000   0.000000
# 62.5         0.000000    0.000000    0.000000  0.000000   0.000000
# 87.5         0.000000    0.000000    0.000000  0.000000   0.000000
# 112.5        0.000000    0.000000    0.000000  0.000000   0.000000
# 137.5        0.000000    0.000000    0.000000  0.000000   0.000000
# 162.5        0.000000    0.000000    0.000000  0.000000   0.000000
# 187.5        0.000000    0.000000    0.000000  0.000000   0.000000
# 212.5        0.000000    0.000000    0.000000  0.000000   0.000000
# 237.5        0.000000    0.000000    0.000000  0.000000   0.000000
# 262.5        0.000000    0.000000    0.000000  0.000000   0.000000
# 287.5        0.000000    0.000000    0.000000  0.000000   0.000000
# 312.5        0.000000    0.000000    0.000000  0.000000   0.000000
# ...

# %%
# # Making Panel C
# %matplotlib inline


# def getExcitationScan(filename):
#     import numpy as np
#     file = open(filename, 'r')
#     graph = [line.split() for line in file if line[0].isdigit()]
#     file.close()
#     return(np.array([float(i[0]) for i in graph]),np.array([float(i[1]) for i in graph]))
# # getExcitationScan('/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2-Batch5/xraySpectroscpy/Acetone_BCA_Se_001.bip')

# def makePanelD(ax):
#     matplotlib.rcParams.update({'font.size': 30})
#     matplotlib.rcParams.update({'font.sans-serif': ['Helvetica']})
#     print(matplotlib.rcParams['font.sans-serif'])
#     import seaborn as sns
#     cols = ['#56AC52','#337848','#F2E92A','#F58320','#822F31','#CC3C39','#475BA6','#78CDDA','#5375BA','#EA3C81'
#         ,'#7E441D','#848585','#8E5EA7','#B9D36C','#000000']
#     colors = sns.color_palette(cols)
#     ncolors = [colors[0],colors[3],colors[7],colors[9],colors[12],colors[11]]
    
#     fileLoc = './DAB2_Batch6_pointMutants/xrayFluorescence/'
#     toPlot = [
#             ['cas9_acetone.bip','cas9'],
#              ['BCA_acetone.bip','Bovine CA'],
#              ['DAB2_acetone_3.bip','DAB2'],
# #              ['DAB2_DC_his_acetone.bip','DAB2 DC His'],
#              ['DAB2_DC_strep_acetone.bip','DAB2 C351A'],
# #              ['DAB2_DD_strep_acetone_2.bip','DAB2 DD Strep'],
#              ['DAB2_DD_strep_acetone.bip','DAB2 D353A'],
#     ]
#     for i, file in enumerate(toPlot):
#         x,y=getExcitationScan(fileLoc+file[0])
#         y=y/max(y[(x>2000) & (x<3500)])+i*2
#         ax.plot(x,y,label=file[1],zorder=5,lw=3,color=ncolors[i])
#         plt.text(2900,(i*2)+0.3,file[1],ha='left',va='bottom')
        
#     top=len(toPlot)*2+0.5
#     plt.xlim(2000,12000)
#     plt.ylim(-0.1,top)
    
    
# #     plt.vlines([2622.39,2815.6,7478.15,8638.86,9572.0],0,6,zorder=0 ,alpha=0.5)
#     plt.vlines([2622.39,6403.84,7478.15,8638.86,9572.0],0,top-0.5,zorder=0 ,alpha=0.5,linestyles='--',lw=3)
# #     plt.text(2622.39,top-0.6,'Cl Ka1',ha='center',va='bottom')
# #     plt.text(7478.15,top-0.6,'Ni Ka1',ha='center',va='bottom')
# #     plt.text(8638.86,top-0.6,'Zn Ka1',ha='center',va='bottom')
# #     plt.text(9572.0,top-0.6,'Zn Kb1',ha='center',va='bottom')
# #     plt.text(6403.84,top-0.6,'Fe Ka1',ha='center',va='bottom')
#     plt.text(2622.39,top-0.6,'Cl',ha='center',va='bottom')
#     plt.text(7478.15,top-0.6,'Ni',ha='center',va='bottom')
#     plt.text(8638.86,top-0.6,'Zn',ha='center',va='bottom')
#     plt.text(9572.0,top-0.6,'Zn',ha='center',va='bottom')
#     plt.text(6403.84,top-0.6,'Fe',ha='center',va='bottom')
# #     plt.legend(loc=[1.05,0.4])
#     plt.xlabel('Energy (eV)')
#     plt.ylabel('Normalized counts')
#     plt.yticks([])
#     plt.xticks(rotation=45)
    
# fig,ax = plt.subplots(figsize=(10,10), frameon=False)
# makePanelD(ax)
# plt.savefig('./../scripts/FigureMakingForBarseqDABPaper/figsForPaper/fig4PanelD.eps',format='eps',bbox_inches='tight')

# plt.show()

# %%
# # Making Panel C
# %matplotlib inline


# def getExcitationScan(filename):
#     import numpy as np
#     file = open(filename, 'r')
#     graph = [line.split() for line in file if line[0].isdigit()]
#     file.close()
#     return(np.array([float(i[0]) for i in graph]),np.array([float(i[1]) for i in graph]))
# # getExcitationScan('/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2-Batch5/xraySpectroscpy/Acetone_BCA_Se_001.bip')

# def makePanelD(ax):
#     matplotlib.rcParams.update({'font.size': 30})
#     import seaborn as sns
#     cols = ['#56AC52','#337848','#F2E92A','#F58320','#822F31','#CC3C39','#475BA6','#78CDDA','#5375BA','#EA3C81'
#         ,'#7E441D','#848585','#8E5EA7','#B9D36C','#000000']
#     colors = sns.color_palette(cols)
#     ncolors = [colors[0],colors[3],colors[7],colors[9],colors[12],colors[11]]
    
#     fileLoc = './DAB2_Batch6_pointMutants/xrayFluorescence/'
#     toPlot = [
#             ['cas9_acetone.bip','cas9'],
#              ['BCA_acetone.bip','Bovine CA'],
#              ['DAB2_acetone_3.bip','DAB2'],
# #              ['DAB2_DC_his_acetone.bip','DAB2 DC His'],
#              ['DAB2_DC_strep_acetone.bip','DAB2 C351A'],
# #              ['DAB2_DD_strep_acetone_2.bip','DAB2 DD Strep'],
#              ['DAB2_DD_strep_acetone.bip','DAB2 D353A'],
#     ]
#     for i, file in enumerate(toPlot):
#         x,y=getExcitationScan(fileLoc+file[0])
#         y=y/max(y[(x>2000) & (x<3500)])+i*2
#         ax.plot(x,y,label=file[1],zorder=5,lw=3,color=ncolors[i])
#         plt.text(2900,(i*2)+0.3,file[1],ha='left',va='bottom')
        
#     top=len(toPlot)*2+0.5
#     plt.xlim(2000,12000)
#     plt.ylim(-0.1,top)
    
    
# #     plt.vlines([2622.39,2815.6,7478.15,8638.86,9572.0],0,6,zorder=0 ,alpha=0.5)
#     plt.vlines([2622.39,6403.84,7478.15,8638.86,9572.0],0,top-0.5,zorder=0 ,alpha=0.5,linestyles='--',lw=3)
# #     plt.text(2622.39,top-0.6,'Cl Ka1',ha='center',va='bottom')
# #     plt.text(7478.15,top-0.6,'Ni Ka1',ha='center',va='bottom')
# #     plt.text(8638.86,top-0.6,'Zn Ka1',ha='center',va='bottom')
# #     plt.text(9572.0,top-0.6,'Zn Kb1',ha='center',va='bottom')
# #     plt.text(6403.84,top-0.6,'Fe Ka1',ha='center',va='bottom')
#     plt.text(2622.39,top-0.6,'Cl',ha='center',va='bottom')
#     plt.text(7478.15,top-0.6,'Ni',ha='center',va='bottom')
#     plt.text(8638.86,top-0.6,'Zn',ha='center',va='bottom')
#     plt.text(9572.0,top-0.6,'Zn',ha='center',va='bottom')
#     plt.text(6403.84,top-0.6,'Fe',ha='center',va='bottom')
# #     plt.legend(loc=[1.05,0.4])
#     plt.xlabel('Energy (eV)')
#     plt.ylabel('Normalized counts')
#     plt.yticks([])
#     plt.xticks(rotation=45)
    
# fig,ax = plt.subplots(figsize=(10,10), frameon=False)
# makePanelD(ax)
# plt.savefig('./../scripts/FigureMakingForBarseqDABPaper/figsForPaper/fig4PanelD.eps',format='eps',bbox_inches='tight')

# plt.show()

# %%
# # Making Panel C
# %matplotlib inline


# def getExcitationScan(filename):
#     import numpy as np
#     file = open(filename, 'r')
#     graph = [line.split() for line in file if line[0].isdigit()]
#     file.close()
#     return(np.array([float(i[0]) for i in graph]),np.array([float(i[1]) for i in graph]))
# # getExcitationScan('/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2-Batch5/xraySpectroscpy/Acetone_BCA_Se_001.bip')

# def makePanelD(ax):
#     fileLoc = '/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2_Batch6_pointMutants/xrayFluorescence/'
#     toPlot = [
#             ['BCA_acetone_loopOnly.bip','BCABufBlank'],
#              ['BCA_acetone.bip','Bovine Erythrocyte CA'],
#              ['DAB2_acetone_2.bip','DAB2'],
#              ['DAB2_acetone_3.bip','DAB2'],
#              ['DAB2_acetone.bip','DAB2'],
#              ['DAB2_DC_his_acetone.bip','DAB2 DC His'],
#              ['DAB2_DC_strep_acetone_loopOnly.bip','DAB2 Blank'],
#              ['DAB2_DC_strep_acetone.bip','DAB2 DC Strep'],
#              ['DAB2_DD_strep_acetone_2.bip','DAB2 DD Strep'],
#              ['DAB2_DD_strep_acetone.bip','DAB2 DD Strep'],
#     ]
#     for i, file in enumerate(toPlot):
#         x,y=getExcitationScan(fileLoc+file[0])
#         y=y/max(y[(x>2000) & (x<3500)])+i*2
#         ax.plot(x,y,label=file[1],zorder=5)
        
#     top=len(toPlot)*2+0.5
#     plt.xlim(2000,12000)
#     plt.ylim(0,top)
    
    
# #     plt.vlines([2622.39,2815.6,7478.15,8638.86,9572.0],0,6,zorder=0 ,alpha=0.5)
#     plt.vlines([2622.39,6403.84,4510.84,7478.15,8638.86,9572.0,10543.72],0,top,zorder=0 ,alpha=0.2,linestyles='--')
#     plt.annotate('Chlorine Ka1',[2622.39,top-0.5],[2722.39,top-0.2],arrowprops={'arrowstyle':'->'})
#     plt.annotate('Nickel Ka1',[7478.15,top-0.5],[6478.15,top-0.2],arrowprops={'arrowstyle':'->'})
#     plt.annotate('Zinc Ka1',[8638.86,top-0.5],[7738.86,top-0.2],arrowprops={'arrowstyle':'->'})
#     plt.annotate('Zinc Kb1',[9572.0,top-0.5],[8672.0,top-0.2],arrowprops={'arrowstyle':'->'})
#     plt.annotate('Iron Ka1',[6403.84,top-0.5],[5503.84,top-0.2],arrowprops={'arrowstyle':'->'})
#     plt.legend(loc=[1.05,0.4])
#     plt.xlabel('Energy (eV)',fontsize=15)
#     plt.ylabel('Normalized counts',fontsize=15)
    
# fig,ax = plt.subplots(figsize=(10,10), frameon=False)
# makePanelD(ax)
# plt.show()

# %%
# # Making Panel C
# %matplotlib inline


# def getExcitationScan(filename):
#     import numpy as np
#     file = open(filename, 'r')
#     graph = [line.split() for line in file if line[0].isdigit()]
#     file.close()
#     return(np.array([float(i[0]) for i in graph]),np.array([float(i[1]) for i in graph]))
# # getExcitationScan('/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2-Batch5/xraySpectroscpy/Acetone_BCA_Se_001.bip')

# def makePanelD(ax):
#     fileLoc = '/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2_Batch6_pointMutants/xrayFluorescence/'
#     toPlot = [
#             ['BCA_acetone_loopOnly.bip','BCABufBlank'],
#              ['BCA_acetone.bip','Bovine Erythrocyte CA'],
#              ['DAB2_acetone_2.bip','DAB2'],
#              ['DAB2_acetone_3.bip','DAB2'],
#              ['DAB2_acetone.bip','DAB2'],
#              ['DAB2_DC_his_acetone.bip','DAB2 DC His'],
#              ['DAB2_DC_strep_acetone_loopOnly.bip','DAB2 Blank'],
#              ['DAB2_DC_strep_acetone.bip','DAB2 DC Strep'],
#              ['DAB2_DD_strep_acetone_2.bip','DAB2 DD Strep'],
#              ['DAB2_DD_strep_acetone.bip','DAB2 DD Strep'],
#     ]
#     for i, file in enumerate(toPlot):
#         x,y=getExcitationScan(fileLoc+file[0])
#         y=10*y/max(y[(x>13500) & (x<15000)])+i*2
#         ax.plot(x,y,label=file[1],zorder=5)
        
#     top=len(toPlot)*2+0.5
#     plt.xlim(2000,15000)
#     plt.ylim(0,top)
    
    
# #     plt.vlines([2622.39,2815.6,7478.15,8638.86,9572.0],0,6,zorder=0 ,alpha=0.5)
#     plt.vlines([2622.39,6403.84,4510.84,7478.15,8638.86,9572.0,10543.72],0,top,zorder=0 ,alpha=0.2,linestyles='--')
#     plt.annotate('Chlorine Ka1',[2622.39,top-0.5],[2722.39,top-0.2],arrowprops={'arrowstyle':'->'})
#     plt.annotate('Nickel Ka1',[7478.15,top-0.5],[6478.15,top-0.2],arrowprops={'arrowstyle':'->'})
#     plt.annotate('Zinc Ka1',[8638.86,top-0.5],[7738.86,top-0.2],arrowprops={'arrowstyle':'->'})
#     plt.annotate('Zinc Kb1',[9572.0,top-0.5],[8672.0,top-0.2],arrowprops={'arrowstyle':'->'})
#     plt.annotate('Iron Ka1',[6403.84,top-0.5],[5503.84,top-0.2],arrowprops={'arrowstyle':'->'})
#     plt.legend(loc=[1.05,0.4])
#     plt.xlabel('Energy (eV)',fontsize=15)
#     plt.ylabel('Normalized counts',fontsize=15)
    
# fig,ax = plt.subplots(figsize=(10,10), frameon=False)
# makePanelD(ax)
# plt.show()

# %%
# Making Panel C
# %matplotlib inline


def getExcitationScan(filename):
    import numpy as np
    file = open(filename, 'r')
    graph = [line.split() for line in file if line[0].isdigit()]
    file.close()
    return(np.array([float(i[0]) for i in graph]),np.array([float(i[1]) for i in graph]))
# getExcitationScan('/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2-Batch5/xraySpectroscpy/Acetone_BCA_Se_001.bip')

def makePanelD(ax):
    fileLoc = '/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2_Batch6_pointMutants/xrayFluorescence/'
    toPlot = [
             ['cas9_acetone.bip','cas9'],
            ['BCA_acetone.bip','Bovine Erythrocyte CA'],
             ['casX_acetone_2ndChunk.bip','casX'],
             ['casX_acetone.bip','casX'],
    ]
    for i, file in enumerate(toPlot):
        x,y=getExcitationScan(fileLoc+file[0])
        y=y/max(y[(x>2000) & (x<3500)])+i*2
        ax.plot(x,y,label=file[1],zorder=5)
        
    top=len(toPlot)*2+0.5
    plt.xlim(2000,12000)
    plt.ylim(0,top)
    
    
#     plt.vlines([2622.39,2815.6,7478.15,8638.86,9572.0],0,6,zorder=0 ,alpha=0.5)
    plt.vlines([2622.39,3313.8,6403.84,8638.86,9572.0],0,top,zorder=0 ,alpha=0.2,linestyles='--')
    plt.annotate('Chlorine Ka1',[2622.39,top-0.5],[2722.39,top-0.2],arrowprops={'arrowstyle':'->'})
    plt.annotate('Potassium Ka1',[3313.8,top-0.5],[3913.8,top-0.2],arrowprops={'arrowstyle':'->'})
    plt.annotate('Zinc Ka1',[8638.86,top-0.5],[7738.86,top-0.2],arrowprops={'arrowstyle':'->'})
    plt.annotate('Zinc Kb1',[9572.0,top-0.5],[8672.0,top-0.2],arrowprops={'arrowstyle':'->'})
    plt.annotate('Iron Ka1',[6403.84,top-0.5],[5503.84,top-0.2],arrowprops={'arrowstyle':'->'})
    plt.legend(loc=[1.05,0.4])
    plt.xlabel('Energy (eV)',fontsize=15)
    plt.ylabel('Normalized counts',fontsize=15)
    
fig,ax = plt.subplots(figsize=(10,10), frameon=False)
makePanelD(ax)

fileLoc = '/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2_Batch6_pointMutants/xrayFluorescence/'
plt.savefig(fileLoc+'casXFull.svg',format='svg',bbox_inches='tight')
plt.savefig(fileLoc+'casXFull.png',bbox_inches='tight')

plt.show()

# %%
# Making Panel C
# %matplotlib inline


def getExcitationScan(filename):
    import numpy as np
    file = open(filename, 'r')
    graph = [line.split() for line in file if line[0].isdigit()]
    file.close()
    return(np.array([float(i[0]) for i in graph]),np.array([float(i[1]) for i in graph]))
# getExcitationScan('/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2-Batch5/xraySpectroscpy/Acetone_BCA_Se_001.bip')

def makePanelD(ax):
    fileLoc = '/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2_Batch6_pointMutants/xrayFluorescence/'
    toPlot = [
             ['cas9_acetone.bip','cas9'],
            ['BCA_acetone.bip','Bovine Erythrocyte CA'],
#              ['casX_acetone_2ndChunk.bip','casX'],
             ['casX_acetone.bip','casX'],
    ]
    for i, file in enumerate(toPlot):
        x,y=getExcitationScan(fileLoc+file[0])
        y=y/max(y[(x>2000) & (x<3500)])+i*2
        ax.plot(x,y,label=file[1],zorder=5)
        
    top=len(toPlot)*2+0.5
    plt.xlim(2000,12000)
    plt.ylim(0,top)
    
    
#     plt.vlines([2622.39,2815.6,7478.15,8638.86,9572.0],0,6,zorder=0 ,alpha=0.5)
    plt.vlines([2622.39,3313.8,8638.86,9572.0],0,top,zorder=0 ,alpha=0.2,linestyles='--')
    plt.annotate('Chlorine Ka1',[2622.39,top-0.5],[2722.39,top-0.2],arrowprops={'arrowstyle':'->'})
    plt.annotate('Potassium Ka1',[3313.8,top-0.5],[3913.8,top-0.2],arrowprops={'arrowstyle':'->'})
    plt.annotate('Zinc Ka1',[8638.86,top-0.5],[7738.86,top-0.2],arrowprops={'arrowstyle':'->'})
    plt.annotate('Zinc Kb1',[9572.0,top-0.5],[8672.0,top-0.2],arrowprops={'arrowstyle':'->'})
#     plt.annotate('Iron Ka1',[6403.84,top-0.5],[5503.84,top-0.2],arrowprops={'arrowstyle':'->'})
    plt.legend(loc=[1.05,0.4])
    plt.xlabel('Energy (eV)',fontsize=15)
    plt.ylabel('Normalized counts',fontsize=15)
    
fig,ax = plt.subplots(figsize=(10,10), frameon=False)
makePanelD(ax)

fileLoc = '/Volumes/Shared/data/Jack/SavageLab/excelSheetsWithEquationsAndData/DAB2_Batch6_pointMutants/xrayFluorescence/'
plt.savefig(fileLoc+'casX.svg',format='svg',bbox_inches='tight')
plt.savefig(fileLoc+'casX.png',bbox_inches='tight')

plt.show()
